# %% [markdown]
# # [4장 1강] 실습문제 - 상관분석
#
# ## 실습 목표
#
# - 공분산과 피어슨 상관계수를 계산해 두 변수 관계의 방향과 강도를 해석할 수 있습니다.
# - 피어슨과 스피어만 상관계수를 비교해 선형 관계와 순위 기반 관계의 차이를 이해할 수 있습니다.
# - 산점도와 상관행렬 히트맵을 활용해 수치형 변수 간 관계를 시각적으로 확인할 수 있습니다.
# - 상관관계와 인과관계를 구분해 비즈니스 관점에서 해석할 수 있습니다.
#
# ## 진행 방식
#
# - 사용 도구: Python, pandas, matplotlib, seaborn, scipy
# - 데이터: `Delivery_Logistics.csv`
# - 공분산·피어슨 → 이상치 영향 → 스피어만 → 상관행렬/히트맵 → 인과관계 주의 순서로 진행합니다.
#
# > 앞선 장에서 다룬 표본추출, 중심극한정리, 표준오차는 이번 실습에서 다시 평가하지 않습니다.

# %% [markdown]
# ## 실습 준비
#
# 아래 셀에서 필요한 라이브러리를 불러오고 `Delivery_Logistics.csv`를 `df`로 불러오세요.

# %%
# pandas, matplotlib.pyplot, seaborn, scipy.stats를 불러오고
# Delivery_Logistics.csv를 df로 불러오세요.

# %% [markdown]
# ---
#
# ## 필수 1. 배송거리와 배송비의 선형 관계 해석하기
#
# ### 문제 1-1. 산점도·공분산·피어슨 상관계수 계산하기
#
# 물류 운영팀은 배송거리가 길어질수록 배송비도 함께 증가하는 경향이 있는지 확인하려고 합니다.
#
# **요구사항**
#
# 1. `distance_km`와 `delivery_cost`가 결측이 아닌 행만 사용하세요.
# 2. 두 변수의 산점도를 그리세요.
# 3. 공분산을 계산하세요.
# 4. 피어슨 상관계수를 계산하세요.
# 5. 피어슨 상관계수의 부호를 기준으로 방향을 해석하세요.
# 6. 아래 강도 기준을 사용해 관계 강도를 해석하세요.
#
# ```text
# |r| >= 0.7        → 강한 상관관계
# 0.3 <= |r| < 0.7 → 중간 정도의 상관관계
# |r| < 0.3         → 약한 상관관계
# ```
#
# 7. 상관관계가 높더라도 `distance_km`가 `delivery_cost`의 유일한 원인이라고 단정하면 안 되는 이유를 한 문장으로 작성하세요.

# %%
# 문제 1-1 코드를 작성하세요.

# %% [markdown]
# ### 문제 1-1 결과 해석
#
# - 공분산:
# - 피어슨 상관계수:
# - 방향:
# - 강도:
# - 인과관계 주의:

# %% [markdown]
# ### 문제 1-2. 배송비 상위 1% 제외 전후 상관관계 비교하기
#
# **요구사항**
#
# 1. `delivery_cost`의 99퍼센타일 값을 구하세요.
# 2. 배송비 상위 1%를 제외한 데이터를 만드세요.
# 3. 전체 데이터의 피어슨 상관계수를 계산하세요.
# 4. 상위 1% 제외 데이터의 피어슨 상관계수를 계산하세요.
# 5. 두 값을 비교해 극단값이 전체 관계를 얼마나 바꾸는지 설명하세요.
#
# **출력 결과**
#
# - 99퍼센타일 기준값
# - 전체 r
# - 상위 1% 제외 r
# - 비교 해석

# %%
# 문제 1-2 코드를 작성하세요.

# %% [markdown]
# ### 문제 1-2 결과 해석
#
# - 99퍼센타일 기준:
# - 전체 데이터 r:
# - 상위 1% 제외 r:
# - 변화:
# - 이상치 영향 해석:

# %% [markdown]
# ---
#
# ## 필수 2. 피어슨과 스피어만 상관계수 비교하기
#
# ### 문제 2-1. 배송거리와 배송평점 관계 비교하기
#
# `delivery_rating`은 1~5점으로 순서가 있는 값입니다. 배송거리가 길어질수록 평점이 낮아지는 경향이 있는지 피어슨과 스피어만을 함께 확인합니다.
#
# **요구사항**
#
# 1. `distance_km`와 `delivery_rating`이 결측이 아닌 행만 사용하세요.
# 2. 피어슨 상관계수를 계산하세요.
# 3. `scipy.stats.spearmanr()`로 스피어만 상관계수와 p-value를 계산하세요.
# 4. 두 상관계수의 방향과 강도를 비교하세요.
# 5. `delivery_rating`처럼 1~5점의 순서형 값에서는 왜 스피어만이 보조 지표로 유용한지 설명하세요.
#
# **출력 결과**
#
# - Pearson r
# - Spearman ρ
# - p-value
# - 두 결과 비교
# - 스피어만 활용 이유

# %%
# 문제 2-1 코드를 작성하세요.

# %% [markdown]
# ### 문제 2-1 결과 해석
#
# - Pearson r:
# - Spearman ρ:
# - p-value:
# - 두 지표의 공통점:
# - 차이:
# - 스피어만이 유용한 이유:

# %% [markdown]
# ---
#
# ## 필수 3. 상관행렬과 히트맵으로 관계 구조 요약하기
#
# ### 문제 3-1. 수치형 변수 상관행렬 만들기
#
# 다음 수치형 변수를 사용하세요.
#
# - `distance_km`
# - `package_weight_kg`
# - `delivery_rating`
# - `delivery_cost`
#
# **요구사항**
#
# 1. 네 변수의 결측값을 제거하세요.
# 2. `corr()`로 상관행렬을 계산하세요.
# 3. `seaborn.heatmap()`으로 상관행렬을 시각화하세요.
# 4. 대각선 값을 제외하고 가장 절댓값이 큰 상관관계 한 쌍을 찾으세요.
# 5. `delivery_rating` 자기 자신을 제외하고, `delivery_rating`과 절댓값 기준 가장 큰 상관을 보이는 변수를 찾으세요.
# 6. 두 관계를 각각 비즈니스 관점에서 1~2문장으로 해석하세요.

# %%
# 문제 3-1 코드를 작성하세요.

# %% [markdown]
# ### 문제 3-1 결과 해석
#
# - 전체에서 가장 강한 상관관계 변수 쌍:
# - 상관계수:
# - delivery_rating과 가장 관계가 큰 변수:
# - 상관계수:
# - 비즈니스 해석:

# %% [markdown]
# ---
#
# ## 심화 1. 상관관계 해석 보고서 작성하기
#
# ### 문제 4-1. 운영 회의용 1분 보고 초안 작성하기
#
# 아래 주제 중 하나를 선택하세요.
#
# 1. `distance_km`와 `delivery_cost`
# 2. `distance_km`와 `delivery_rating`
# 3. 문제 3-1에서 확인한 `delivery_rating`과 가장 관계가 큰 변수
#
# **요구사항**
#
# 1. 관찰된 상관관계의 방향과 강도를 한 문장으로 요약하세요.
# 2. 상관관계를 인과관계로 단정할 수 없는 이유를 한 문장으로 작성하세요.
# 3. 추가로 확인할 변수 2개 이상을 제시하세요.
# 4. 전체 내용을 4~5문장의 운영 회의용 보고 초안으로 정리하세요.
#
# **추가 확인 변수 예시**
#
# - `package_weight_kg`
# - `delivery_mode`
# - `vehicle_type`
# - `region`
# - `weather_condition`

# %% [markdown]
# ### 문제 4-1 답안 작성 공간
#
# - 선택 주제:
# - 관찰된 관계:
# - 인과관계 주의:
# - 추가 확인 변수:
# - 운영 회의용 보고 초안:

# %% [markdown]
# ---
#
# ## 실습 마무리
#
# 1. 공분산의 부호는 무엇을 의미하나요?
# 2. 공분산만으로 관계의 강도를 판단하기 어려운 이유는 무엇인가요?
# 3. 피어슨 상관계수는 어떤 관계를 측정하나요?
# 4. 스피어만 상관계수는 어떤 관계를 측정하나요?
# 5. 상관계수와 함께 산점도를 확인해야 하는 이유는 무엇인가요?
# 6. 상관행렬의 대각선 값이 항상 1인 이유는 무엇인가요?
# 7. 높은 상관관계가 인과관계를 의미하지 않는 이유는 무엇인가요?
