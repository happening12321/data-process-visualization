# %% [markdown]
# # [3장 2강] 실습문제 - 표본분포와 중심극한정리
#
# ## 실습 목표
#
# - `delivery_cost`에서 표본평균을 반복 계산하여 표본평균의 분포를 만들 수 있습니다.
# - 표본 크기에 따라 표본평균 분포의 중심과 퍼짐이 어떻게 달라지는지 설명할 수 있습니다.
# - 중심극한정리의 의미를 실제 데이터 시뮬레이션 결과와 연결할 수 있습니다.
# - 표준오차 `SE = σ / √n`을 계산하고 시뮬레이션 결과와 비교할 수 있습니다.
# - 표본 크기가 커질수록 평균 추정이 왜 더 안정적인지 설명할 수 있습니다.
#
# ## 진행 방식
#
# - 사용 도구: Python, pandas, numpy, matplotlib
# - 데이터: `Delivery_Logistics.csv`
# - `delivery_cost`를 모집단 데이터로 사용합니다.
#
# > 3장 1강에서 다룬 단순 무작위·층화·군집·계통 표집과 대표성 비교는 이번 실습에서 다시 평가하지 않습니다.

# %% [markdown]
# ## 실습 준비
#
# 아래 셀에서 `pandas`, `numpy`, `matplotlib.pyplot`을 불러오고 `Delivery_Logistics.csv`를 `df`로 불러오세요.
#
# `delivery_cost`의 결측값을 제거한 뒤 `population`으로 저장하세요.

# %%
# 필요한 라이브러리를 불러오고
# Delivery_Logistics.csv를 df로 불러오세요.
# delivery_cost의 결측값을 제거해 population으로 저장하세요.

# %% [markdown]
# ---
#
# ## 필수 1. 표본평균의 분포 만들기
#
# ### 문제 1-1. 원래 배송비 분포와 표본평균 분포 비교하기
#
# 물류 분석팀은 개별 배송비 데이터와 여러 표본에서 계산한 평균값들이 어떤 차이를 보이는지 확인하려고 합니다.
#
# **요구사항**
#
# 1. `population`의 `delivery_cost` 분포를 히스토그램으로 그리세요.
# 2. 표본 크기 `n=30`으로 표본을 1,000번 반복 추출하세요.
# 3. 각 표본의 평균을 `sample_means`에 저장하세요.
# 4. `sample_means`의 히스토그램을 별도로 그리세요.
# 5. 모집단 평균과 표본평균들의 평균을 출력하세요.
# 6. 원래 데이터 분포와 표본평균 분포의 모양 차이를 2~3문장으로 설명하세요.
#
# **주의**
#
# 이번 문제에서 중요한 것은 개별 표본을 어떻게 대표성 있게 뽑는지가 아니라, **같은 크기의 표본을 반복 추출했을 때 표본평균들이 어떤 분포를 만드는지 확인하는 것**입니다.

# %%
# 문제 1-1 코드를 작성하세요.

# %% [markdown]
# ### 문제 1-1 결과 해석
#
# - 모집단 평균:
# - 표본평균들의 평균:
# - 원래 delivery_cost 분포의 특징:
# - 표본평균 분포의 특징:
# - 두 분포가 다른 이유:

# %% [markdown]
# ### 문제 1-2. 표본 크기 5·30·100 비교하기
#
# **요구사항**
#
# 1. 표본 크기 `5`, `30`, `100`을 사용하세요.
# 2. 각 표본 크기마다 표본평균을 1,000번 계산하세요.
# 3. 세 표본평균 분포를 서로 비교할 수 있도록 시각화하세요.
# 4. 각 분포의 평균과 표준편차를 계산하세요.
# 5. 표본 크기가 커질수록 다음 항목이 어떻게 변하는지 설명하세요.
#    - 표본평균 분포의 중심
#    - 표본평균 분포의 퍼짐
#
# **출력 결과**
#
# | 표본 크기 | 표본평균들의 평균 | 표본평균들의 표준편차 |
# |---:|---:|---:|

# %%
# 문제 1-2 코드를 작성하세요.

# %% [markdown]
# ### 문제 1-2 결과 해석
#
# - n=5:
# - n=30:
# - n=100:
# - 표본 크기가 커질수록 중심은 어떻게 되는가?:
# - 표본 크기가 커질수록 퍼짐은 어떻게 되는가?:

# %% [markdown]
# ---
#
# ## 필수 2. 중심극한정리 확인하기
#
# ### 문제 2-1. 비정규 모집단에서도 표본평균 분포가 안정되는지 확인하기
#
# `delivery_cost`의 원래 분포가 완벽한 정규분포가 아니더라도, 표본평균의 분포는 표본 크기가 커질수록 정규분포에 가까워질 수 있습니다.
#
# **요구사항**
#
# 1. `delivery_cost` 원본 분포를 히스토그램으로 다시 확인하세요.
# 2. `n=5`, `n=30`, `n=100`에서 각각 표본평균을 1,000번 계산하세요.
# 3. 세 표본평균 분포를 비교하세요.
# 4. `n`이 커질수록 분포가 더 대칭적이고 종 모양에 가까워지는지 관찰하세요.
# 5. 다음 문장을 완성하세요.
#
# > 중심극한정리에서 정규분포에 가까워지는 대상은 ________ 자체가 아니라 ________의 분포입니다.

# %%
# 문제 2-1 코드를 작성하세요.

# %% [markdown]
# ### 문제 2-1 결과 해석
#
# - 원래 delivery_cost 분포:
# - n=5 표본평균 분포:
# - n=30 표본평균 분포:
# - n=100 표본평균 분포:
# - 중심극한정리 해석:

# %% [markdown]
# ---
#
# ## 필수 3. 표준오차와 표본 크기 관계 확인하기
#
# ### 문제 3-1. 이론적 표준오차와 시뮬레이션 결과 비교하기
#
# **요구사항**
#
# 1. `population`의 표준편차 `σ`를 계산하세요.
# 2. `n=5`, `30`, `100`에 대해 이론적 표준오차를 계산하세요.
#
# ```text
# SE = σ / √n
# ```
#
# 3. 각 표본 크기에서 1,000번 시뮬레이션한 표본평균들의 표준편차를 계산하세요.
# 4. 이론적 SE와 시뮬레이션 SE를 DataFrame으로 비교하세요.
# 5. 표본 크기가 커질수록 두 값이 어떻게 변하는지 설명하세요.
#
# **출력 결과**
#
# | n | 이론적 SE | 시뮬레이션 SE |
# |---:|---:|---:|

# %%
# 문제 3-1 코드를 작성하세요.

# %% [markdown]
# ### 문제 3-1 결과 해석
#
# - n=5 이론적/시뮬레이션 SE:
# - n=30 이론적/시뮬레이션 SE:
# - n=100 이론적/시뮬레이션 SE:
# - 표본 크기 증가와 SE의 관계:
# - 평균 추정의 정밀도와 연결한 해석:

# %% [markdown]
# ### 문제 3-2. 표본 크기가 4배가 되면 표준오차는 어떻게 변하는가?
#
# **요구사항**
#
# 1. 같은 모집단 표준편차를 사용하세요.
# 2. `n=25`, `100`, `400`의 표준오차를 계산하세요.
# 3. `25 → 100`, `100 → 400`은 각각 표본 크기가 몇 배 증가한 것인지 확인하세요.
# 4. 표준오차가 실제로 약 절반씩 감소하는지 확인하세요.
# 5. 왜 표본 크기를 4배 늘려야 표준오차가 절반이 되는지 공식과 연결해 설명하세요.

# %%
# 문제 3-2 코드를 작성하세요.

# %% [markdown]
# ### 문제 3-2 결과 해석
#
# - n=25의 SE:
# - n=100의 SE:
# - n=400의 SE:
# - 4배 증가 시 변화:
# - 이유:

# %% [markdown]
# ---
#
# ## 심화 1. 추론통계로 연결하기
#
# ### 문제 4-1. 왜 표본 하나의 평균으로 모집단을 추론할 수 있는가?
#
# 분석팀이 다음 질문을 했습니다.
#
# > "우리가 실제 업무에서 얻는 것은 표본 하나뿐인데, 왜 그 평균으로 전체 배송비 수준을 추론할 수 있나요?"
#
# **요구사항**
#
# 다음 세 자료를 근거로 4~5문장으로 설명하세요.
#
# 1. `delivery_cost` 원본 분포
# 2. `n=30` 또는 `n=100`에서의 표본평균 분포
# 3. 표본 크기별 표준오차 비교표
#
# 설명에는 반드시 다음 내용이 포함되어야 합니다.
#
# - 표본평균 자체도 분포를 가진다는 점
# - 표본 크기가 충분히 크면 표본평균 분포가 정규분포에 가까워진다는 점
# - 표준오차가 표본평균의 변동성을 나타낸다는 점
# - 이 개념들이 다음 강의의 신뢰구간으로 연결된다는 점

# %% [markdown]
# ### 문제 4-1 답안 작성 공간
#
# - 설명:
# - 실제 업무에서 주의할 점:

# %% [markdown]
# ---
#
# ## 실습 마무리
#
# 1. 표본분포란 무엇인가요?
# 2. 표본평균들의 평균은 무엇에 가까워지나요?
# 3. 중심극한정리에서 정규분포에 가까워지는 것은 원래 데이터인가요, 표본평균의 분포인가요?
# 4. 표준오차는 무엇을 의미하나요?
# 5. `SE = σ / √n`에서 `n`이 커질수록 SE는 어떻게 변하나요?
# 6. 표본 크기를 4배로 늘리면 SE가 절반이 되는 이유는 무엇인가요?
# 7. 표본평균 분포와 표준오차가 왜 신뢰구간의 기초가 되나요?
