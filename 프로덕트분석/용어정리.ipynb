# %%
# 프로덕트 분석 : 사용자 행동 데이터를 분석해 서비스의 문제를 찾고 개선을 위한 의사결정을 돕는 과정
# -> 쇼핑몰 방문자는 늘었는데 구매자가 비슷하다. 상품 조회 (클릭 수), 장바구니, 결제 순서 등의 사용자 행동을
# 살펴보면 어느 과정에서 딜레이가 있었는지 어느 부분을 개선해야할지 정할 수 있다

# KPI: 비즈니스의 핵심 목표가 얼마나 달성되고 있는지 판단하기 위해 중요하게 관리하는 지표
# -> 월간 유료 강의 구매자 수가 KPI가 될 수 있다

# 보조 지표: KPI의 변화와 그 배경을 구체적으로 이해하기 위해 함께 확인하는 지표

# 허무 지표: 숫자나 내용 자체는 좋아보이지만 현재 목표나 KPI와는 무관하거나 연결이 약한 지표

# 프레임워크: 문제를 일정한 기분에 따라 나누어 생각하도록 돕는 틀
# 매출이 줄었다면 유입의 감소인지 첫 이용자수의 감소인지, 재이용, 재방문이 줄었는지 등
# 여러 요인을 확인할 수 있는데 이렇게 분석할 질문들을 정리하는 틀을 프레임워크라고 한다

# AARRR: 사용자 행동을 획득, 첫 가치 경험, 유지, 매출 발생, 추천 다섯 관점으로 나누어 분석하는 방법
# -> Kant DS 를 광고를 통해 방문하고 첫 강의를 듣고 재수강하고 유료 강의를 구매하고 친구에게 추천하는 행동을 나누어 생각할 수 있다

#
