# %%
# 추론 통계: 일부 데이터를 이용하여 특성을 추정하거나 전체에 대한 주장을 검토하는 통계
# -> 고객 100명의 구매금액을 조사해 전체 고객의 평균 구매금액이 기존과 다른지 판단

# 가설 검정 : 표본을 이용해 전체에 대한 기본 가정을 기각할 만큼 근거가 있는지 판단하는 방법
# -> 평균 50,000원이라는 가정과 표본 평균이 53,200원이 얼마나 잘 맞는지 검초

# 귀무 가설 : 검정을 시작할 때 기분으로 두는 가설
# -> 고객의 평균 구매 금액은 50,000원일 거야

# 대립 가설 : 귀무 가설과 반대되는 주장, 검정을 통해 근거를 확인하려는 가설
# -> 전체 고객의 평균 구매금액은 50,000이 아니고 50,000원 보다 크거나 작은 경우가 있어

# p-value
# 유의수준 alpha : 귀무 가설이 맞는데도 잘못 기각하는 오류를 어느 수준까지 허용할 것인가
# -> 보통 0.05의 수치를 많이 사용하며 alpha값이 0.05라면 귀무 가설이 참인 상태에서 검정을 반복할 때
# -> 잘못 기각하는 비율을 5% 수준으로 통제

# p-value p : 귀무 가설과 가정이 맞을 때 현재와 같거나 더 극단적인 검정 결과가 나올 확률
# -> 0.018이면 귀무가설에서 현재와 같거나 더 극단적인 결과가 나올 확률이 1.8%라는 뜻
# 귀무가설이 맞을 확률이 1.8%인 것 아님 XX

# 귀무가설을 기각하는 경우
# -> 대립 가설을 지지할 만한 통계적 근거가 있었다는 거지요
# P=0.05고 p-value가 0.018이면 0.018 < 0.05 이므로 귀무가설을 기각한다
# -> 평균 구매금액이 기존과 다르다고 볼 근거가 있다

# 귀무가설을 기각하지 못함
# -> 현재 데이터에서 귀무가설을 기각할 만큼 충분한 근거를 찾기 못함
# ALPHA=0.05이고  p-value가 0.18이면 0.18>0.05 이므로 기각하지 못한다
# 평균이 같다가 아닌 평균이 50,000이 아니라고 볼 근거가 충분하지 않다 라고 해석

# 귀무 가설 : 기준, 검정을 시작할 때 기준으로 두는 가설
# -> 피고인은 무죄다
# 대립 가설 : 귀무 가설과 반대되는 주장, 검정을 통해 근거를 확이하려는 가설
# -> 피고인은 무죄가 아니다

# 유의 수준
# -> 실제로 무죄인 피고인을 재판했을 때 잘못 유죄 판결을 내릴 위험을 5% 수준까지만 감수하겠다고 미리 정해두는 것

# p-value: 귀무가설과 검정의 가정이 맞을 때 현재와 같거나 더 극단적인 검정 결과가 나올 확률
# -> p-value가 0.18이면 피고인이 무죄라고 가정해도 지금 같은 증거가 나올 확률이 1.8%정도 이다
# 단, 피고인이 무죄일 확률이 1.8%이라는 뜻은 아니다
# 무죄라고 가정했을 때, 유죄라는 증거가 나올 확률을 의미

# 변동성: 값들이 얼마나 제각각인지

# 표준편차: 평균 주변에 값이 얼마나 퍼져있는지
# -> 표준편차가 크면 값들이 차이가 전반적으로 크다

# 분산: 값들의 퍼짐 정도, 표준편차를 제곱한 값
# -> 시험 점수의 표준편차가 10점이면 분산은 100점입니다

# 통계적 유의성: 검정 결과가 미리 정한 기각 기준을 충족하여 차이를 뒷받침할 통계적 근거가 있다는 뜻
# -> p-value < alpha 면 유의하다고 판단
# -> 평균 배송 시간이 30분에서 29분으로 줄고 p=0.002라면 alpha = 0.05에서 통계적으로 유의한 차이다

# 정규 분포: 평균 중심으로 좌우가 대칭인 종 모양 분포

# 정규성: 검정에서 필요한 분포가 이 모양에서 크게 벗어나지 않는다는 가정

# 치우친 분포와 이상치
# -> 한쪽 방향으로 값이 길게 이어지는 모습
# 이상치는 대부분의 값과 비교해 유난히 멀리 떨어진 값

# 등분산성: 비교하는 집단들의 분산이 같다고 가정
# 등분산성은 평균의 같음을 나타내는 값이 아니라 퍼짐 정도가 같음을 가정하는 부분

# T - 통계량: 관찰된 평균 차이가 표준오차의 몇 배인지를 나타내는 검증용 숫자
# -> 평균이 75점, 기준이 70점, 표준 오차가 약 0.57점이면 t값은 약 8.6이고
# 평균의 차이가 표준오차의 약 8.6배정도라는 뜻

# 독립표본 t 검정: 서로 독립된 두 집단의 모평균이 같은지를 비교하는 검정
# -> 광고 A 와 B 를 본 서로 다른 고객의 평균 구매금액을 비교한다.

# 

#일원분산분석(아노바): 하나의 집단 구분 기준에 따라 나뉜 여러 집단의 모평균이 모두 같은지 검정하는 방법
# -> 교육방법 a,b,c 로 교육을 진행한 뒤 점수를 비교한다

# f통계량: 집단 간 평균 제곱을 집단 내 평균 제곱으로 나눈 값이다
# -> 귀무가설과 가정이 맞을 때 두 평균제곱은 같은 분산을 추정한다
# -> f 값이 클수록 집단 간 차이가 내부 퍼짐에 비해 크다

# 카이제곱 통계량: 관측 빈도가 기대 빈도에서 얼마나 벗어났는지를 모든 칸에 걸쳐 합친 숫자
# -> 일반, 재구매를 표로 나타내어 칸으로 나타내면
# -> (30-40)의 제곱 % 40=2.5고 나머지칸도 같은 방식으로 계산하면 약 8.3이다
# -> x의 제곱 = 모든 칸의 (관측 - 기대)의 제곱 % 기대값

# 카이제곱의 독립성 검정: 두 범주형 변수가 독립이라는 가설을 교차표의 관측빈도로 검토하는 방법
# -> 이용기기(모바일, pc)와 유료 회원 가입 여부(ㅇ,x)과 관련되어있는지 검정한다
# 귀무가설 - 두 변수가 독립적이다
# 대립가설 - 두 변수는 독립적이지 않다(=연관이 있다)

# 피어슨 상관계수: 두 숫자형 선형관계를 -1 ... +1 로 나타내는 지표
# -> 한 달의 광고비와 그 달의 매출을 한 쌍으로 묶어 선형 관계로 표현

# 양의 상관: 같은 방향
# -> 공부를 많이 하면 성적 향상

# 음의 상관: 반대 방향
# -> 광고비를 많이 사용했는데 매출 감소

# 결정계수: 0.95면 이 모델의 설명력이 95%다
# -> 1에 가까울 수록 좋음

# 상관관계: 두 변수가 함께 달라지는 통계적 관계
# -> 광고 노출이 많은 날 주문도 많다라는 것은 상관관계가 있다라고 볼 수 있다

# 인과관계: 어떤 조건을 바꿨을 때 그 변화 때문에 결과가 달라지는 관계
# -> 다른 조건을 같게 설정한 뒤 광고 노출을 기존과 다르게 하여 주문량이 달라지는 것을 알아보는 것

# 단순 선셩 회귀: x로 y의 평균적인 관계를 직선으로 나타내는 방법
# -> 배달 거리 변수를 이용하여 평균적인 배달 시간을 설명하고 예측할 수 있다
# -> 거리와 날씨를 함께 사용하면 x가 여러 개가 도리 수 있다

# 독립 변속, 종속 변수

# 회계 계수와 기울기:회계계수는 회귀식을 정하는 숫자. 기울기는 x가 1단위 증가할 때 직선의 예측값이 얼마나 달라지는지
# -> 

# 절편
# 오차와 잔차:

# 가드레일 지표: 실험으로 인해 허용하기 어려운 부작용이 생기는지 확인하는 지표
# -> 추천 영상 시청 완료율이 올라도 앱 이탈율이 크게 높아지는 현상이 발생한다면 부작용을 확인해야 함

# 전환율: 
# 클릭률: 

# 검정력 분석: 유의 수준, 검정력, 효과 크기, 표본 크기의 관계를 이용해 실험을 계획하는 법
# -> 효과 크기 d =0.2 유의수준 0.05 검정력 0.80을 정하고 필요한 그룹당 인원을 구한다

# 제 1종 오류: 실제로 차이가 없는데 귀무가설을 기각하여 차이 있다고 판단하는 오류

# 제 2종 오류:실제로 특정한 차이가 있는데 귀무가설을 기각하지 못하는 오류

#cohen's d: 두 집단의 평균 차이를 공통 표준편차로 나눈 표준화 효과 크기
# -> 평균 차이 2,000원 공통 표준편차 10,000원 이면 d=2,000%10,000=0.2
